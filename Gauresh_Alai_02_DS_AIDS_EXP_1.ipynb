# %% [markdown]
# # **Experiment 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import zscore

# %%
df1=pd.read_csv('student_info.csv')
df1
# Out:
#    Student ID     Name  Age Grade
# 0         101    Alice   20     A
# 1         102      Bob   21     B
# 2         103  Charlie   19     A
# 3         104    David   22     C
# 4         105      Eve   20     B

# %%
df2=pd.read_csv('student_scores.csv')
df2
# Out:
#    Student ID  Math Score  English Score  Science Score
# 0         101          85             78             92
# 1         102          76             88             81
# 2         103          90             95             89
# 3         104          65             70             75
# 4         105          80             82             87

# %%
df3 = pd.concat([df1, df2], axis=0)
df3
# Out:
#    Student ID     Name   Age Grade  Math Score  English Score  Science Score
# 0         101    Alice  20.0     A         NaN            NaN            NaN
# 1         102      Bob  21.0     B         NaN            NaN            NaN
# 2         103  Charlie  19.0     A         NaN            NaN            NaN
# 3         104    David  22.0     C         NaN            NaN            NaN
# 4         105      Eve  20.0     B         NaN            NaN            NaN
# 0         101      NaN   NaN   NaN        85.0           78.0           92.0
# 1         102      NaN   NaN   NaN        76.0           88.0           81.0
# 2         103      NaN   NaN   NaN        90.0           95.0           89.0
# 3         104      NaN   NaN   NaN        65.0           70.0           75.0
# 4         105      NaN   NaN   NaN        80.0           82.0           87.0
